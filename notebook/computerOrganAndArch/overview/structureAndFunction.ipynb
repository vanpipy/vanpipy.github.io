# %% [markdown]
# # Structure and Function
#
# ## Function
#
# * Data processing
# * Data storage
# * Data movement
# * Control
#
# ## Structure
#
# * Central processing unit (CPU)
# * Main memory
# * Input/Output (I/O)
# * System interconnection
#
# ## Top-Level Structure

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 10))

c1 = plt.Circle((2, 11), 3, edgecolor='blue', facecolor='none')
c1_1 = plt.Circle((0.5, 12), 1.1, edgecolor='blue', facecolor='none')
c1_2 = plt.Circle((3.5, 12), 1.1, edgecolor='blue', facecolor='none')
c1_3 = plt.Circle((2, 9.25), 1.1, edgecolor='blue', facecolor='none')
c1_4 = plt.Circle((2, 11), 1.1, edgecolor='blue', facecolor='none')

ax.add_patch(c1)
ax.add_patch(c1_1)
ax.add_patch(c1_2)
ax.add_patch(c1_3)
ax.add_patch(c1_4)
ax.text(2, 13.5, 'COMPUTER', ha='center', va='center')
ax.text(0.5, 12, 'I/O', ha='center', va='center', fontsize=10)
ax.text(3.5, 12, 'Main\nmemory', ha='center', va='center', fontsize=8)
ax.text(2, 9.25, 'CPU', ha='center', va='center', fontsize=10)
ax.text(2, 11, 'System\nbus', ha='center', va='center', fontsize=10)

c2 = plt.Circle((12, 6), 3, edgecolor='green', facecolor='none')
c2_1 = plt.Circle((10.5, 7), 1.1, edgecolor='green', facecolor='none')
c2_2 = plt.Circle((13.5, 7), 1.1, edgecolor='green', facecolor='none')
c2_3 = plt.Circle((12, 4.25), 1.1, edgecolor='green', facecolor='none')
c2_4 = plt.Circle((12, 6), 1.1, edgecolor='green', facecolor='none')

ax.add_patch(c2)
ax.add_patch(c2_1)
ax.add_patch(c2_2)
ax.add_patch(c2_3)
ax.add_patch(c2_4)
ax.text(12, 8.5, 'CPU', ha='center', va='center')
ax.text(10.5, 7, 'ALU', ha='center', va='center')
ax.text(13.5, 7, 'Registers', ha='center', va='center')
ax.text(12, 4.25, 'Control\nunit', ha='center', va='center')
ax.text(12, 6, 'Internal\nbus', ha='center', va='center')

c3 = plt.Circle((2, 2), 3, edgecolor='red', facecolor='none')
c3_1 = plt.Circle((0.5, 3), 1.1, edgecolor='red', facecolor='none')
c3_2 = plt.Circle((3.5, 3), 1.1, edgecolor='red', facecolor='none')
c3_3 = plt.Circle((2, 0.25), 1.1, edgecolor='red', facecolor='none')
c3_4 = plt.Circle((2, 2), 1.1, edgecolor='red', facecolor='none')

ax.add_patch(c3)
ax.add_patch(c3_1)
ax.add_patch(c3_2)
# ax.add_patch(c3_3)
ax.add_patch(c3_4)
ax.text(2, 4.5, 'CONTROL UNIT', ha='center', va='center')
ax.text(0.5, 3, 'Sequencing\nlogic', ha='center', va='center')
ax.text(3.5, 3, 'Control\nmemory', ha='center', va='center')
ax.text(2, 2, 'Control unit\nregisters and\ndecoders', ha='center', va='center', fontsize=8)

ax.set_aspect('equal')
ax.set_xlim(-2, 15)
ax.set_ylim(-2, 15)

plt.show()
